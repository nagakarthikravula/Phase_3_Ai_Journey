# %% [markdown]
# <a href="https://colab.research.google.com/github/nagakarthikravula/Phase_3_Ai_Journey/blob/main/week9_embeddings_day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install sentence-transformers

# %%
from sentence_transformers import SentenceTransformer, util

model = SentenceTransformer('all-MiniLM-L6-v2')

sentences = [
    "The dog chased the ball",
    "A puppy ran after a sphere",
    "I love eating pizza",
    "She enjoys having pasta for dinner",
    "Machine learning is a subset of AI",
    "I am listening to music by edhsheeran",
    "I am playing ed sheeran song on spotify",
    "I love listening to music"
]

embeddings = model.encode(sentences)

print("Shape of one embedding:", embeddings[0].shape)
print("First 5 numbers of sentence 1 embedding:", embeddings[0][:5])

pairs = [
    (0,1),
    (2,3),
    (0,2),
    (0,4),
    (2,4),
    (5,6),
    (2,6),
    (2,7)
]

for i,j in pairs:
  score = util.cos_sim(embeddings[i],embeddings[j])
  print(f"Sentence {i+1} vs Sentence {j+1}: {score.item(): .4f}")
  print(f"  '{sentences[i]}")
  print(f"  '{sentences[j]}")
  print()
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# Shape of one embedding: (384,)
# First 5 numbers of sentence 1 embedding: [0.0354518  0.04642522 0.02453485 0.02836235 0.05788202]
# Sentence 1 vs Sentence 2:  0.4988
#   'The dog chased the ball
#   'A puppy ran after a sphere
#
# Sentence 3 vs Sentence 4:  0.4100
#   'I love eating pizza
#   'She enjoys having pasta for dinner
#
# Sentence 1 vs Sentence 3:  0.0619
#   'The dog chased the ball
#   'I love eating pizza
#
# Sentence 1 vs Sentence 5:  0.0969
#   'The dog chased the ball
#   'Machine learning is a subset of AI
#
# Sentence 3 vs Sentence 5:  0.0580
#   'I love eating pizza
#   'Machine learning is a subset of AI
#
# Sentence 6 vs Sentence 7:  0.5778
#   'I am listening to music by edhsheeran
#   'I am playing ed sheeran song on spotify
#
# Sentence 3 vs Sentence 7:  0.1188
#   'I love eating pizza
#   'I am playing ed sheeran song on spotify
#
# Sentence 3 vs Sentence 8:  0.4137
#   'I love eating pizza
# ...
